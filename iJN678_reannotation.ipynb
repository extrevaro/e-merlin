# %% [markdown]
# # Reannotation of iJN678 to locus tag in *NC_000911.1*

# %%
import cobra
import pandas as pd

# %%
model_name = 'iJN678_autotrophic.mat'
species = 'synechocystis_sp_pcc_6803'
model_filepath = '/'.join(['models', model_name])
matlab_model = cobra.io.load_matlab_model(model_filepath)
new_model = cobra.io.load_matlab_model('/'.join(['models', 'iSynCJ816.mat']))
# Out:
# No defined compartments in model iJN678. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, p, u
# This model seems to have metCharge instead of metCharges field. Will use metCharge for what metCharges represents.
# No defined compartments in model iSynCJ816. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, l, p, u, x, y

# %% [markdown]
# In the following cell I create a file called *'new_model_annotation.csv'*, where are all the **GPRs of reactions with shared IDs in both models**. This file is going to be used for directly **translate the GPRs of *iJN678* to the newest version**.

# %%
new_annotation_filepath = '/'.join(['data',species,'new_model_annotation.csv'])

shared_reactions = set([r.id for r in matlab_model.reactions]).intersection(set([r.id for r in new_model.reactions]))

new_annotation = { 'Reaction' : list(shared_reactions),
                   'GPR_iJN678' : [ matlab_model.reactions.get_by_id(reaction).gene_reaction_rule for reaction in shared_reactions ],
                   'GPR_iSynCJ816' : [ new_model.reactions.get_by_id(reaction).gene_reaction_rule for reaction in shared_reactions ] }

annotation_df = pd.DataFrame.from_dict(new_annotation)
annotation_df.to_csv(new_annotation_filepath)
annotation_df
# Out:
#             Reaction    GPR_iJN678               GPR_iSynCJ816
# 0              HGPHT       slr1736                 SGL_RS08065
# 1               CYSS  cysK or cysM  SGL_RS02310 or SGL_RS06370
# 2            FMETTRS           fmt                 SGL_RS13995
# 3              NDPK9          ndkR                 SGL_RS12365
# 4              RBFSa          ribH                 SGL_RS06985
# ..               ...           ...                         ...
# 764  DGDG183_9_12_15       slr1508                 SGL_RS09310
# 765              SBP   fbp or glpX                 SGL_RS09170
# 766         EX_akg_e
# 767           ADCYRS          cbiP                 SGL_RS15620
# 768           HIBDkt          mmsB                 SGL_RS13640
#
# [769 rows x 3 columns]

# %%
from tools.importExcelModel import *
model_df = model_to_dataframe(matlab_model)
model_df[0]
# Out:
#     Abbreviation                                           Reaction  \
# 0        EX_ac_e                                          ac_e -->
# 1    34DHOXPEGOX  34dhmald_c + h_c + nadh_c <=> 34dhoxpeg_c + nad_c
# 2    EX_photon_e                                      photon_e <--
# 3        34HPPOR               34hpp_c + o2_c --> co2_c + hgentis_c
# 4       EX_ca2_e                                         ca2_e <=>
# ..           ...                                                ...
# 858       CBFCpp  2.0 h_c + 2.0 pcox_p + pqh2_p --> 4.0 h_p + 2....
# 859   CYO1b2_syn  4.0 h_c + 0.5 o2_u + 2.0 pcrd_u --> h2o_u + 2....
# 860       PHETA1            akg_c + phe__L_c <=> glu__L_c + phpyr_c
# 861       ORNTAC             acorn_c + glu__L_c <=> acglu_c + orn_c
# 862         ABTA            4abut_c + akg_c --> glu__L_c + sucsal_c
#
#                                                    GPR  Lower bound  \
# 0                                                               0.0
# 1                                              sll0990      -1000.0
# 2                                                            -100.0
# 3                                                  ppd          0.0
# 4                                                           -1000.0
# ..                                                 ...          ...
# 858  petA and petB and petC and petC and petC and p...          0.0
# 859  (ctaD or ctaD) and (ctaC or ctaC) and (ctaE or...          0.0
# 860            aspC or sll0480 or aspC or hisC or hisC      -1000.0
# 861                                        argJ or ama      -1000.0
# 862                                       argD or hemL          0.0
#
#      Upper bound  Objective  Confidence Score  \
# 0         1000.0        0.0                 4
# 1         1000.0        0.0                 4
# 2            0.0        0.0                 4
# 3         1000.0        0.0                 4
# 4         1000.0        0.0                 4
# ..           ...        ...               ...
# 858       1000.0        0.0                 4
# 859       1000.0        0.0                 4
# 860       1000.0        0.0                 4
# 861       1000.0        0.0                 4
# 862       1000.0        0.0                 4
#
#                                              Subsystem  \
# 0                               Extracellular exchange
# 1    Phenylalanine tyrosine and tryptophan biosynth...
# 2                               Extracellular exchange
# 3    Phenylalanine tyrosine and tryptophan biosynth...
# 4                               Extracellular exchange
# ..                                                 ...
# 858                          Oxidative phosphorylation
# 859                                     Photosynthesis
# 860  Phenylalanine tyrosine and tryptophan biosynth...
# 861          Urea cycle and metabolism of amino groups
# 862          Urea cycle and metabolism of amino groups
#
#                                            Description
# 0                                     Acetate exchange
# 1    3,4-Dihydroxyphenylethyleneglycol NAD+ oxidore...
# 2                                      Photon exchange
# 3         4 Hydroxyphenylpyruvateoxygen oxidoreductase
# 4                                     Calcium exchange
# ..                                                 ...
# 858                  Cytochrome b6/f complex periplasm
# 859    Cytochrome c oxidase, synechocystis (2 protons)
# 860                         Phenylalanine transaminase
# 861                           Ornithine transacetylase
# 862                       4-aminobutyrate transaminase
#
# [863 rows x 9 columns]

# %%
gprs_to_rename = { row['Reaction'] : {'iJN678': row['GPR_iJN678'],
                                      'iSynCJ816': row['GPR_iSynCJ816']}
                   for index, row in annotation_df.iterrows() }

model_df[0] = model_df[0].set_index('Abbreviation')
for reaction in shared_reactions:
    model_df[0].loc[reaction, 'GPR'] = gprs_to_rename[reaction]['iSynCJ816']

model_df[0]
# Out:
#                                                        Reaction  \
# Abbreviation
# EX_ac_e                                               ac_e -->
# 34DHOXPEGOX   34dhmald_c + h_c + nadh_c <=> 34dhoxpeg_c + nad_c
# EX_photon_e                                       photon_e <--
# 34HPPOR                    34hpp_c + o2_c --> co2_c + hgentis_c
# EX_ca2_e                                             ca2_e <=>
# ...                                                         ...
# CBFCpp        2.0 h_c + 2.0 pcox_p + pqh2_p --> 4.0 h_p + 2....
# CYO1b2_syn    4.0 h_c + 0.5 o2_u + 2.0 pcrd_u --> h2o_u + 2....
# PHETA1                  akg_c + phe__L_c <=> glu__L_c + phpyr_c
# ORNTAC                   acorn_c + glu__L_c <=> acglu_c + orn_c
# ABTA                    4abut_c + akg_c --> glu__L_c + sucsal_c
#
#                                                             GPR  Lower bound  \
# Abbreviation
# EX_ac_e                                                                  0.0
# 34DHOXPEGOX                                         SGL_RS04900      -1000.0
# EX_photon_e                                                           -100.0
# 34HPPOR                                             SGL_RS15355          0.0
# EX_ca2_e                                                             -1000.0
# ...                                                         ...          ...
# CBFCpp        petA and petB and petC and petC and petC and p...          0.0
# CYO1b2_syn    (ctaD or ctaD) and (ctaC or ctaC) and (ctaE or...          0.0
# PHETA1                SGL_RS13785 or SGL_RS08515 or SGL_RS16530      -1000.0
# ORNTAC                                              SGL_RS10330      -1000.0
# ABTA                                                SGL_RS04875          0.0
#
#               Upper bound  Objective  Confidence Score  \
# Abbreviation
# EX_ac_e            1000.0        0.0                 4
# 34DHOXPEGOX        1000.0        0.0                 4
# EX_photon_e           0.0        0.0                 4
# 34HPPOR            1000.0        0.0                 4
# EX_ca2_e           1000.0        0.0                 4
# ...                   ...        ...               ...
# CBFCpp             1000.0        0.0                 4
# CYO1b2_syn         1000.0        0.0                 4
# PHETA1             1000.0        0.0                 4
# ORNTAC             1000.0        0.0                 4
# ABTA               1000.0        0.0                 4
#
#                                                       Subsystem  \
# Abbreviation
# EX_ac_e                                  Extracellular exchange
# 34DHOXPEGOX   Phenylalanine tyrosine and tryptophan biosynth...
# EX_photon_e                              Extracellular exchange
# 34HPPOR       Phenylalanine tyrosine and tryptophan biosynth...
# EX_ca2_e                                 Extracellular exchange
# ...                                                         ...
# CBFCpp                                Oxidative phosphorylation
# CYO1b2_syn                                       Photosynthesis
# PHETA1        Phenylalanine tyrosine and tryptophan biosynth...
# ORNTAC                Urea cycle and metabolism of amino groups
# ABTA                  Urea cycle and metabolism of amino groups
#
#                                                     Description
# Abbreviation
# EX_ac_e                                        Acetate exchange
# 34DHOXPEGOX   3,4-Dihydroxyphenylethyleneglycol NAD+ oxidore...
# EX_photon_e                                     Photon exchange
# 34HPPOR            4 Hydroxyphenylpyruvateoxygen oxidoreductase
# EX_ca2_e                                       Calcium exchange
# ...                                                         ...
# CBFCpp                        Cytochrome b6/f complex periplasm
# CYO1b2_syn      Cytochrome c oxidase, synechocystis (2 protons)
# PHETA1                               Phenylalanine transaminase
# ORNTAC                                 Ornithine transacetylase
# ABTA                               4-aminobutyrate transaminase
#
# [863 rows x 8 columns]

# %%
missing_to_reannotate = set([r.id for r in matlab_model.reactions if len(r.gene_reaction_rule)>0 ])-shared_reactions
len(missing_to_reannotate)
# Out:
# 83

# %%
missing_reactions_df = model_df[0].loc[list(missing_to_reannotate)]
missing_reactions_df
# Out:
#                                                        Reaction  \
# Abbreviation
# ACLS                      h_c + 2.0 pyr_c --> alac__S_c + co2_c
# CYTBDu                       0.5 o2_u + pqh2_u --> h2o_u + pq_u
# ARGDr                    arg__L_c + h2o_c --> citr__L_c + nh4_c
# PYK3                      gdp_c + h_c + pep_c --> gtp_c + pyr_c
# THZPSN        atp_c + cys__L_c + dxyl5p_c + tyr__L_c --> 4hb...
# ...                                                         ...
# AMID2                           h2o_c + pad_c --> nh4_c + pac_c
# TDPGDH                        dtdpglu_c --> dtdp4d6dg_c + h2o_c
# PPTGF_Syn                       peptido_syn_c --> peptido_syn_p
# ASNN                      asn__L_c + h2o_c --> asp__L_c + nh4_c
# BCAROHX       caro_c + h_c + nadph_c + o2_c --> bcryptox_c +...
#
#                                  GPR  Lower bound  Upper bound  Objective  \
# Abbreviation
# ACLS          ilvB and ilvG and ilvN          0.0       1000.0        0.0
# CYTBDu                 cydA and cydB          0.0       1000.0        0.0
# ARGDr                        sll1336          0.0       1000.0        0.0
# PYK3                    pykF or pykF          0.0       1000.0        0.0
# THZPSN                 thiG or ycf40          0.0       1000.0        0.0
# ...                              ...          ...          ...        ...
# AMID2                           nylA          0.0       1000.0        0.0
# TDPGDH                  rfbB or rfbB          0.0       1000.0        0.0
# PPTGF_Syn                    slr0488          0.0       1000.0        0.0
# ASNN                         sll0422          0.0       1000.0        0.0
# BCAROHX                          bhy          0.0       1000.0        0.0
#
#               Confidence Score  \
# Abbreviation
# ACLS                         4
# CYTBDu                       4
# ARGDr                        4
# PYK3                         4
# THZPSN                       4
# ...                        ...
# AMID2                        4
# TDPGDH                       4
# PPTGF_Syn                    4
# ASNN                         4
# BCAROHX                      4
#
#                                                       Subsystem  \
# Abbreviation
# ACLS                        C5-Branched dibasic acid metabolism
# CYTBDu                                           Photosynthesis
# ARGDr                           Arginine and proline metabolism
# PYK3                                 Glycolysis/Gluconeogenesis
# THZPSN                                      Thiamine metabolism
# ...                                                         ...
# AMID2         Phenylalanine tyrosine and tryptophan biosynth...
# TDPGDH                             Nucleotide sugars metabolism
# PPTGF_Syn                            Peptidoglycan biosynthesis
# ASNN                                        Nitrogen metabolism
# BCAROHX                                 Carotenoid Biosynthesis
#
#                                                     Description
# Abbreviation
# ACLS                                      Acetolactate synthase
# CYTBDu        Cytochrome oxidase bd (plastocianine-8  2 prot...
# ARGDr                                        Arginine deiminase
# PYK3                                         Pyruvate kinase(3)
# THZPSN                             Thiazole phosphate synthesis
# ...                                                         ...
# AMID2                                                   Amidase
# TDPGDH                              DTDPglucose 4,6-dehydratase
# PPTGF_Syn                                               Flypase
# ASNN                                             L-asparaginase
# BCAROHX                               Beta-carotene hydroxylase
#
# [83 rows x 8 columns]

# %%
genes_missing = set([ gene for reaction in missing_to_reannotate for gene in [g.id for g in matlab_model.reactions.get_by_id(reaction).genes]])
len(genes_missing)
# Out:
# 166

# %%
reaction_name_matching = [r for r in new_model.reactions if r.name in missing_reactions_df.Description.tolist()]
for reaction in reaction_name_matching[60:]:
    display(missing_reactions_df.loc[missing_reactions_df.Description==reaction.name, ['Reaction', 'GPR', 'Description']])
    print(missing_reactions_df.loc[missing_reactions_df.Description==reaction.name, ['Reaction', 'GPR', 'Description']].Reaction.values)
    display(reaction)
    print(reaction.gene_reaction_rule)
# Out:
#                                                        Reaction  \
# Abbreviation
# CBFC2pp       2.0 ficytc6_p + 2.0 h_c + pqh2_p --> 2.0 focyt...
# CBFCpp        2.0 h_c + 2.0 pcox_p + pqh2_p --> 4.0 h_p + 2....
#
#                                                             GPR  \
# Abbreviation
# CBFC2pp       petA and petB and petC and petC and petC and p...
# CBFCpp        petA and petB and petC and petC and petC and p...
#
#                                     Description
# Abbreviation
# CBFC2pp       Cytochrome b6/f complex periplasm
# CBFCpp        Cytochrome b6/f complex periplasm
# ['2.0 ficytc6_p + 2.0 h_c + pqh2_p --> 2.0 focytc6_p + 4.0 h_p + pq_p'
#  '2.0 h_c + 2.0 pcox_p + pqh2_p --> 4.0 h_p + 2.0 pcrd_p + pq_p']
# <Reaction CBFCpf at 0x7f1068447b80>
# SGL_RS05875 and SGL_RS07315 and SGL_RS13200 and SGL_RS10620 and SGL_RS07320 and SGL_RS18155 and SGL_RS13205 and SGL_RS13610 and SGL_RS10475 and ssl3803 and SGL_RS16365 and sml0004 and SGL_RS05245 and SGL_RS05250 and SGL_RS05240 and SGL_RS05235 and SGL_RS05230 and SGL_RS07605 and SGL_RS17600 and SGL_RS04660 and SGL_RS08580 and SGL_RS08585 and SGL_RS08590 and SGL_RS03465 and SGL_RS12650 and SGL_RS17175
#                                                        Reaction  \
# Abbreviation
# PSI           2.0 fdxo_2_2_c + 2.0 pcrd_u + 2.0 photon_c -->...
#
#                                                             GPR  \
# Abbreviation
# PSI           psaA and psaB and psaC and psaD and psaE and p...
#
#                                Description
# Abbreviation
# PSI           Photosystem I (plastocyanin)
# ['2.0 fdxo_2_2_c + 2.0 pcrd_u + 2.0 photon_c --> 2.0 fdxrd_c + 2.0 pcox_u']
# <Reaction PSI_2a at 0x7f10684d2ef0>
# SGL_RS02560 and (SGL_RS17240 or SGL_RS02600) and SGL_RS03975 and SGL_RS09810 and SGL_RS12695 and SGL_RS02435 and SGL_RS09960 and SGL_RS17820 and SGL_RS06305 and SGL_RS06310 and SGL_RS09805 and SGL_RS17825 and SGL_RS04090 and SGL_RS12620 and SGL_RS11240 and SGL_RS06050
#                                                        Reaction  \
# Abbreviation
# PSII          h2o_u + 2.0 h_c + 2.0 photon_c + pq_u --> 2.0 ...
#
#                                                             GPR  \
# Abbreviation
# PSII          psbA3 and psbA1 and psbA2 and psbD and psbD2 a...
#
#                  Description
# Abbreviation
# PSII          Photosystem II
# ['h2o_u + 2.0 h_c + 2.0 photon_c + pq_u --> 2.0 h_u + 0.5 o2_u + pqh2_u']
# <Reaction PSIIa at 0x7f10681956f0>
# SGL_RS11935 and SGL_RS11735 and SGL_RS08205 and SGL_RS08200 and SGL_RS03265 and SGL_RS02070 and SGL_RS09330 and SGL_RS10440 and SGL_RS14825 and SGL_RS16825 and SGL_RS18130 and SGL_RS01910 and SGL_RS11645 and SGL_RS08090 and SGL_RS04525 and SGL_RS12880 and SGL_RS14050 and sml0003 and SGL_RS04440 and SGL_RS07800 and SGL_RS13125 and SGL_RS04535 and SGL_RS04540 and SGL_RS04545 and smr0009 and SGL_RS07325 and SGL_RS04530 and SGL_RS02645 and SGL_RS02635
#                                      Reaction      GPR Description
# Abbreviation
# PPTGF_Syn     peptido_syn_c --> peptido_syn_p  slr0488     Flypase
# ['peptido_syn_c --> peptido_syn_p']
# <Reaction PPTGF_Syn_1 at 0x7f10678a4c40>
# SGL_RS14090
#                                                       Reaction   GPR  \
# Abbreviation
# MPOMOR2       nadp_c + omppp9_c --> dvpchlld_c + h_c + nadph_c  bchE
#
#                                                     Description
# Abbreviation
# MPOMOR2       magnesium-protoporphyrin-IX 13-monomethyl este...
# ['nadp_c + omppp9_c --> dvpchlld_c + h_c + nadph_c']
# <Reaction MPOMOR2_1 at 0x7f106757cd90>
# SGL_RS14820
#                                                            Reaction      GPR  \
# Abbreviation
# AGPAT183_9_12_15  1odec91215eg3p_c + octe_9_12_15_ACP_c --> ACP_...  sll1848
#
#                                                         Description
# Abbreviation
# AGPAT183_9_12_15  1-octadec-enoyl-sn-glycerol 3-phosphate O-acyl...
# ['1odec91215eg3p_c + octe_9_12_15_ACP_c --> ACP_c + pa183_9_12_15_c']
# <Reaction AGPAT183_6_9_12 at 0x7f1066debf10>
# SGL_RS12400
#                                                            Reaction      GPR  \
# Abbreviation
# AGPAT183_9_12_15  1odec91215eg3p_c + octe_9_12_15_ACP_c --> ACP_...  sll1848
#
#                                                         Description
# Abbreviation
# AGPAT183_9_12_15  1-octadec-enoyl-sn-glycerol 3-phosphate O-acyl...
# ['1odec91215eg3p_c + octe_9_12_15_ACP_c --> ACP_c + pa183_9_12_15_c']
# <Reaction AGPAT183_9_12_16 at 0x7f1066c5a7d0>
# SGL_RS12400

# %% [markdown]
# I reviewed those genes with name matching one by one and if they were the same reaction, I added them to a file called *'gpr_manual_annotations.csv'*, that is composed by 2 columns, **representing Reaction -> GPR relationships**.

# %%
manual_annotation_filepath = '/'.join(['data',species,'gpr_manual_annotations.csv'])
manual_annotation_df = pd.read_csv(manual_annotation_filepath)
manual_annotation_df
# Out:
#             Reaction                                                GPR
# 0               HMBS                                        SGL_RS07710
# 1              HISTD                         SGL_RS03870 or SGL_RS04465
# 2             3HAD40                                        SGL_RS08755
# 3             3OAR40              SGL_RS07245 or SGL_RS12965 or sll5079
# 4                PSI  SGL_RS02560 and (SGL_RS17240 or SGL_RS02600) a...
# 5               RBPC                        SGL_RS13415 and SGL_RS13425
# 6               RBCh                        SGL_RS13415 and SGL_RS13425
# 7              CBFC2  SGL_RS05875 and SGL_RS07315 and SGL_RS13200 an...
# 8              CBFCu  SGL_RS05875 and SGL_RS07315 and SGL_RS13200 an...
# 9          CYO1b_syn  (SGL_RS09865 or SGL_RS05540) and (SGL_RS09075 ...
# 10        CYO1b2_syn  (SGL_RS09865 or SGL_RS05540) and (SGL_RS09075 ...
# 11       CYO1bpp_syn  (SGL_RS09865 or SGL_RS05540) and (SGL_RS09075 ...
# 12      CYO1b2pp_syn  (SGL_RS09865 or SGL_RS05540) and (SGL_RS09075 ...
# 13         PPTGS_Syn                         SGL_RS04790 or SGL_RS05320
# 14               PPC                                        SGL_RS11290
# 15             DCTPD                                        SGL_RS10020
# 16            DCTPD2                                        SGL_RS10020
# 17        SUCDpp_syn        SGL_RS15205 and SGL_RS08045 and SGL_RS06730
# 18             AIRCr                        SGL_RS18210 and SGL_RS16805
# 19           DHNAPHT                                        SGL_RS09385
# 20            DHPPDA                                        SGL_RS13965
# 21             AMID2                                        SGL_RS15160
# 22             AMID3                                        SGL_RS15160
# 23            CYNTAH                                        SGL_RS14780
# 24              CSND                                        SGL_RS06770
# 25            THZPSN                        SGL_RS13810 and SGL_RS14260
# 26             HCO3E                         SGL_RS13835 or SGL_RS10110
# 27              UREA  SGL_RS08455 and SGL_RS11790 and SGL_RS04480 an...
# 28          NDH1_4pp  sll8031 and SGL_RS06280 and SGL_RS09760 and SG...
# 29            ALAD_L                                        SGL_RS02960
# 30              ACLS        SGL_RS13860 and SGL_RS09150 and SGL_RS09105
# 31             ACHBS        SGL_RS13860 and SGL_RS09150 and SGL_RS09105
# 32            CBFCpp  SGL_RS05875 and SGL_RS07315 and SGL_RS13200 an...
# 33           CBFC2pp  SGL_RS05875 and SGL_RS07315 and SGL_RS13200 an...
# 34              PSII  SGL_RS11935 and SGL_RS11735 and SGL_RS08205 an...
# 35         PPTGF_Syn                                        SGL_RS14090
# 36           MPOMOR2                                        SGL_RS14820
# 37  AGPAT183_9_12_15                                        SGL_RS12400
# 38             GLYCL        SGL_RS11955 and SGL_RS07170 and SGL_RS12745
# 39              GLUN                                        SGL_RS09060
# 40          DNAMTn2r                                        SGL_RS13525
# 41              GLNS                         SGL_RS11925 or SGL_RS04340
# 42             GLUDy                                        SGL_RS16330
# 43             CBMKr                                        SGL_RS18255
# 44           NOR_syn                                        SGL_RS14775
# 45            TDPDRR                                        SGL_RS02095
# 46            TDPGDH                         SGL_RS09825 or SGL_RS15130
# 47            TDPDRE                         SGL_RS03555 or SGL_RS12335
# 48             ARGDr                                        SGL_RS17085
# 49            THRD_L                                        SGL_RS06140
# 50              ASNN                         SGL_RS11775 or SGL_RS15655
# 51              HMBS                                        SGL_RS07710

# %%
for reaction in manual_annotation_df.Reaction.tolist():
    model_df[0].loc[reaction, 'GPR'] = manual_annotation_df.loc[manual_annotation_df.Reaction==reaction].GPR.tolist()[0]

model_df[0]
# Out:
#                                                        Reaction  \
# Abbreviation
# EX_ac_e                                               ac_e -->
# 34DHOXPEGOX   34dhmald_c + h_c + nadh_c <=> 34dhoxpeg_c + nad_c
# EX_photon_e                                       photon_e <--
# 34HPPOR                    34hpp_c + o2_c --> co2_c + hgentis_c
# EX_ca2_e                                             ca2_e <=>
# ...                                                         ...
# CBFCpp        2.0 h_c + 2.0 pcox_p + pqh2_p --> 4.0 h_p + 2....
# CYO1b2_syn    4.0 h_c + 0.5 o2_u + 2.0 pcrd_u --> h2o_u + 2....
# PHETA1                  akg_c + phe__L_c <=> glu__L_c + phpyr_c
# ORNTAC                   acorn_c + glu__L_c <=> acglu_c + orn_c
# ABTA                    4abut_c + akg_c --> glu__L_c + sucsal_c
#
#                                                             GPR  Lower bound  \
# Abbreviation
# EX_ac_e                                                                  0.0
# 34DHOXPEGOX                                         SGL_RS04900      -1000.0
# EX_photon_e                                                           -100.0
# 34HPPOR                                             SGL_RS15355          0.0
# EX_ca2_e                                                             -1000.0
# ...                                                         ...          ...
# CBFCpp        SGL_RS05875 and SGL_RS07315 and SGL_RS13200 an...          0.0
# CYO1b2_syn    (SGL_RS09865 or SGL_RS05540) and (SGL_RS09075 ...          0.0
# PHETA1                SGL_RS13785 or SGL_RS08515 or SGL_RS16530      -1000.0
# ORNTAC                                              SGL_RS10330      -1000.0
# ABTA                                                SGL_RS04875          0.0
#
#               Upper bound  Objective  Confidence Score  \
# Abbreviation
# EX_ac_e            1000.0        0.0                 4
# 34DHOXPEGOX        1000.0        0.0                 4
# EX_photon_e           0.0        0.0                 4
# 34HPPOR            1000.0        0.0                 4
# EX_ca2_e           1000.0        0.0                 4
# ...                   ...        ...               ...
# CBFCpp             1000.0        0.0                 4
# CYO1b2_syn         1000.0        0.0                 4
# PHETA1             1000.0        0.0                 4
# ORNTAC             1000.0        0.0                 4
# ABTA               1000.0        0.0                 4
#
#                                                       Subsystem  \
# Abbreviation
# EX_ac_e                                  Extracellular exchange
# 34DHOXPEGOX   Phenylalanine tyrosine and tryptophan biosynth...
# EX_photon_e                              Extracellular exchange
# 34HPPOR       Phenylalanine tyrosine and tryptophan biosynth...
# EX_ca2_e                                 Extracellular exchange
# ...                                                         ...
# CBFCpp                                Oxidative phosphorylation
# CYO1b2_syn                                       Photosynthesis
# PHETA1        Phenylalanine tyrosine and tryptophan biosynth...
# ORNTAC                Urea cycle and metabolism of amino groups
# ABTA                  Urea cycle and metabolism of amino groups
#
#                                                     Description
# Abbreviation
# EX_ac_e                                        Acetate exchange
# 34DHOXPEGOX   3,4-Dihydroxyphenylethyleneglycol NAD+ oxidore...
# EX_photon_e                                     Photon exchange
# 34HPPOR            4 Hydroxyphenylpyruvateoxygen oxidoreductase
# EX_ca2_e                                       Calcium exchange
# ...                                                         ...
# CBFCpp                        Cytochrome b6/f complex periplasm
# CYO1b2_syn      Cytochrome c oxidase, synechocystis (2 protons)
# PHETA1                               Phenylalanine transaminase
# ORNTAC                                 Ornithine transacetylase
# ABTA                               4-aminobutyrate transaminase
#
# [863 rows x 8 columns]

# %%
model_df[1] = model_df[1].rename(columns={'Formula' : 'Charged formula'})
model_df[0].reset_index(inplace=True)

# %%
reannotated_model = dataframe_to_model(model_df[0], model_df[1])
reannotated_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ec_SynAuto = 0.08835348353030417</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.0003987</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>3.7</td>
#       <td>1</td>
#       <td>99.99%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>0.0002874</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.0002658</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.0006614</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0006022</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>2.42</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>0.8795</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.01495</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.002541</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>0.0002676</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mobd_e</td>
#       <td>EX_mobd_e</td>
#       <td>0.0002676</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.0003346</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>no3_e</td>
#       <td>EX_no3_e</td>
#       <td>0.7964</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon_e</td>
#       <td>EX_photon_e</td>
#       <td>54.1</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.06099</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.01676</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>0.0002658</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>rdmbzi_c</td>
#       <td>SK_rdmbzi_c</td>
#       <td>1.97E-05</td>
#       <td>14</td>
#       <td>0.01%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5mdru1p_c</td>
#       <td>DM_5mdru1p_c</td>
#       <td>-0.0005959</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>-5.585</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
not_in_new_annotation = set([g for r in reannotated_model.reactions for g in [gene.id for gene in r.genes] if g.startswith('SGL')==False ])
len(not_in_new_annotation)
# Out:
# 72

# %%
not_annotated_genes_in_new_model = set([gene for gene in not_in_new_annotation if gene in [g.id for g in new_model.genes]])
len(not_annotated_genes_in_new_model)
# Out:
# 7

# %%
not_annotated_genes_in_matlab_model = set([gene for gene in not_in_new_annotation if gene in [g.id for g in matlab_model.genes]])
len(not_annotated_genes_in_matlab_model)
# Out:
# 67

# %%
not_annotated_genes_in_new_model.intersection(not_annotated_genes_in_matlab_model)
# Out:
# {'sll8031', 'ssl3803'}

# %%
annotation_table_filepath = '/'.join(['data',species,'gene_info.csv'])
annot_table = pd.read_csv(annotation_table_filepath)
genes_with_annotated_traditional_names = set([gene for gene in not_in_new_annotation if gene in annot_table.gene_name.tolist()])
len(genes_with_annotated_traditional_names)
# Out:
# 26

# %%
annot_table
# Out:
#         locus_tag    gene_name    accession old_locus_tag    start      end  \
# 0     SGL_RS01370  SGL_RS01370  NC_005232.1       slr6001      243     3053
# 1     SGL_RS00010  SGL_RS00010  NC_005229.1       sll5002      574     1017
# 2     SGL_RS00635  SGL_RS00635  NC_005230.1       sll7002      706     1287
# 3     SGL_RS01880  SGL_RS01880  NC_000911.1       slr0612      811     1494
# 4     SGL_RS00015  SGL_RS00015  NC_005229.1       sll5003     1136     1540
# ...           ...          ...          ...           ...      ...      ...
# 3737  SGL_RS18370  SGL_RS18370  NC_000911.1       slr0607  3569134  3569523
# 3738  SGL_RS18375        hisIE  NC_000911.1       slr0608  3569672  3570319
# 3739  SGL_RS18380  SGL_RS18380  NC_000911.1       slr0609  3570424  3571575
# 3740  SGL_RS18385  SGL_RS18385  NC_000911.1       slr0610  3571711  3572403
# 3741  SGL_RS01875          sds  NC_000911.1       slr0611  3573271  3574242
#
#      strand                                       gene_product  \
# 0         +  hybrid sensor histidine kinase/response regulator
# 1         -                               hypothetical protein
# 2         -                           IS701 family transposase
# 3         +                             pseudouridine synthase
# 4         -                    DUF5615 family PIN-like protein
# ...     ...                                                ...
# 3737      +  cyclic nucleotide-binding domain-containing pr...
# 3738      +  bifunctional phosphoribosyl-AMP cyclohydrolase...
# 3739      +                                GTP-binding protein
# 3740      +                           ABC transporter permease
# 3741      +                     solanesyl diphosphate synthase
#
#                                                   COG           uniprot  \
# 0                      Signal transduction mechanisms               NaN
# 1                                   No COG annotation               NaN
# 2               Replication, recombination and repair               NaN
# 3     Translation, ribosomal structure and biogenesis               NaN
# 4                                   No COG annotation               NaN
# ...                                               ...               ...
# 3737                   Signal transduction mechanisms               NaN
# 3738              Nucleotide transport and metabolism  A0A6P1VM37_9SYNC
# 3739                                 Function unknown               NaN
# 3740                                 Function unknown               NaN
# 3741                Coenzyme transport and metabolism  A0A6P1VKP0_9SYNC
#
#       operon
# 0       Op97
# 1      Op712
# 2     Op2588
# 3      Op465
# 4      Op686
# ...      ...
# 3737   Op766
# 3738  Op2513
# 3739   Op489
# 3740   Op108
# 3741  Op1759
#
# [3742 rows x 11 columns]

# %% [markdown]
# After reannotating te model following the modifications indicated in *'gpr_manual_annotations.csv'*, there are still 72 genes missing the new annotation. Of those, 7 are in the newes annotated model and 67 in our model, sharing 2 old annotated genes. Partially, this is due to the **annotation following traditional names** (26 genes with traditional names), so I will parse those names **using the gene annotation obtained during the modulome workflow**.

# %%
in_gene_name_column_dict = { gene : set(annot_table.loc[annot_table.gene_name==gene].locus_tag.tolist())
                             for gene in not_in_new_annotation if gene in annot_table.gene_name.tolist()}

in_gene_name_column_dict
# Out:
# {'ilvC': {'SGL_RS17215'},
#  'pyrG': {'SGL_RS10805'},
#  'atpA': {'SGL_RS02675'},
#  'atpH': {'SGL_RS02680'},
#  'ilvA': {'SGL_RS06140'},
#  'atpC': {'SGL_RS09710'},
#  'ndhI': {'SGL_RS16995'},
#  'psaK': {'SGL_RS02600', 'SGL_RS17240'},
#  'menB': {'SGL_RS06810'},
#  'atpD': {'SGL_RS09705'},
#  'gcvT': {'SGL_RS12745'},
#  'pdxA': {'SGL_RS16360'},
#  'hoxU': {'SGL_RS09745'},
#  'ndhK': {'SGL_RS10730'},
#  'psaB': {'SGL_RS06310'},
#  'atpB': {'SGL_RS02700'},
#  'hoxF': {'SGL_RS09755'},
#  'cydB': {'SGL_RS05015'},
#  'psaA': {'SGL_RS06305'},
#  'psaM': {'SGL_RS04090'},
#  'trpB': {'SGL_RS16740'},
#  'atpE': {'SGL_RS02695'},
#  'trpA': {'SGL_RS03395'},
#  'ndhC': {'SGL_RS10725'},
#  'psaC': {'SGL_RS12620'},
#  'psaJ': {'SGL_RS09805'}}

# %%
annot_table.loc[annot_table.gene_name=='psaK']
# Out:
#         locus_tag gene_name    accession old_locus_tag    start      end  \
# 530   SGL_RS02600      psaK  NC_000911.1       ssr0390   156391   156651
# 3520  SGL_RS17240      psaK  NC_000911.1       sll0629  3322377  3322649
#
#      strand                                gene_product  \
# 530       +  photosystem I reaction center subunit PsaK
# 3520      -  photosystem I reaction center subunit PsaK
#
#                                                     COG           uniprot  \
# 530   Intracellular trafficking, secretion, and vesi...  A0A6P1VFL7_9SYNC
# 3520  Intracellular trafficking, secretion, and vesi...               NaN
#
#      operon
# 530   Op765
# 3520  Op578

# %%
matlab_model.genes.psaK
# Out:
# <Gene psaK at 0x7f10a5714190>

# %%
matlab_model.reactions.PSI
# Out:
# <Reaction PSI at 0x7f10957f3a30>

# %%
matlab_model.reactions.PSI_2
# Out:
# <Reaction PSI_2 at 0x7f108bc3d6c0>

# %%
matlab_model.reactions.PSI_2.gene_reaction_rule == matlab_model.reactions.PSI.gene_reaction_rule
# Out:
# True

# %%
new_model.reactions.PSIa
# Out:
# <Reaction PSIa at 0x7f1080c17220>

# %%
target_reactions = [r.id for r in matlab_model.genes.get_by_id('psaK').reactions]
model_df[0].loc[model_df[0].Abbreviation.isin(target_reactions)]
# Out:
#     Abbreviation                                           Reaction  \
# 462          PSI  2.0 fdxo_2_2_c + 2.0 pcrd_u + 2.0 photon_c -->...
# 828        PSI_2  2.0 fdxo_2_2_c + 2.0 focytc6_u + 2.0 photon_c ...
#
#                                                    GPR  Lower bound  \
# 462  SGL_RS02560 and (SGL_RS17240 or SGL_RS02600) a...          0.0
# 828  psaA and psaB and psaC and psaD and psaE and p...          0.0
#
#      Upper bound  Objective  Confidence Score       Subsystem  \
# 462       1000.0        0.0                 4  Photosynthesis
# 828       1000.0        0.0                 4  Photosynthesis
#
#                          Description
# 462     Photosystem I (plastocyanin)
# 828  Photosystem I (ferrocytochrome)

# %%
model_df[0].loc[model_df[0].Abbreviation=='PSI_2', 'GPR'] = reannotated_model.reactions.PSI.gene_reaction_rule
model_df[0].loc[model_df[0].Abbreviation.isin(target_reactions)]
# Out:
#     Abbreviation                                           Reaction  \
# 462          PSI  2.0 fdxo_2_2_c + 2.0 pcrd_u + 2.0 photon_c -->...
# 828        PSI_2  2.0 fdxo_2_2_c + 2.0 focytc6_u + 2.0 photon_c ...
#
#                                                    GPR  Lower bound  \
# 462  SGL_RS02560 and (SGL_RS17240 or SGL_RS02600) a...          0.0
# 828  SGL_RS02560 and (SGL_RS17240 or SGL_RS02600) a...          0.0
#
#      Upper bound  Objective  Confidence Score       Subsystem  \
# 462       1000.0        0.0                 4  Photosynthesis
# 828       1000.0        0.0                 4  Photosynthesis
#
#                          Description
# 462     Photosystem I (plastocyanin)
# 828  Photosystem I (ferrocytochrome)

# %%
model_df[0].loc[model_df[0].GPR.str.contains('|'.join(list(in_gene_name_column_dict.keys())))]
# Out:
#     Abbreviation                                           Reaction  \
# 108        CTPS1  atp_c + nh4_c + utp_c --> adp_c + ctp_c + 2.0 ...
# 178    CYTBDpp_1                 0.5 o2_p + pqh2_p --> h2o_p + pq_p
# 180       CYTBDu                 0.5 o2_u + pqh2_u --> h2o_u + pq_u
# 182      GLYCL_2  co2_c + mlthf_c + nadh_c + nh4_c --> gly_c + n...
# 334        KARA2     2ahbut_c + h_c + nadph_c --> 23dhmp_c + nadp_c
# 390         NPHS                        sbzcoa_c --> coa_c + dhna_c
# 423       PDX5PS  dxyl5p_c + nad_c + phthr_c --> co2_c + 2.0 h2o...
# 511       SERD_L                         ser__L_c --> nh4_c + pyr_c
# 545        TRPS1    3ig3p_c + ser__L_c --> g3p_c + h2o_c + trp__L_c
# 796      NDH1_3u  co2_p + h2o_c + 3.0 h_c + nadph_c + pq_u --> 3...
# 797      NDH1_1u  4.0 h_c + nadph_c + pq_u --> 3.0 h_u + nadp_c ...
# 826      NDH1_2p  4.0 h_c + nadh_c + pq_p --> 3.0 h_p + nad_c + ...
# 827        ATPSu  3.0 adp_c + 14.0 h_u + 3.0 pi_c --> 3.0 atp_c ...
# 833      NDH1_2u  4.0 h_c + nadh_c + pq_u --> 3.0 h_u + nad_c + ...
# 834      NDH1_1p  4.0 h_c + nadph_c + pq_p --> 3.0 h_p + nadp_c ...
#
#                                                    GPR  Lower bound  \
# 108                                               pyrG          0.0
# 178                                      cydA and cydB          0.0
# 180                                      cydA and cydB          0.0
# 182                                               gcvT          0.0
# 334                                               ilvC          0.0
# 390                                               menB          0.0
# 423                                               pdxA          0.0
# 511                                               ilvA          0.0
# 545                                      trpA and trpB          0.0
# 796  ndhA and ndhB and ndhC and ndhE and ndhG and n...          0.0
# 797  (ndhD or ndhD2) and ndhF and ndhA and ndhB and...          0.0
# 826  (ndhD or ndhD2) and ndhF and ndhA and ndhB and...          0.0
# 827  atpI and atpG and atpF and atpA and atpD and a...          0.0
# 833  (ndhD or ndhD2) and ndhF and ndhA and ndhB and...          0.0
# 834  (ndhD or ndhD2) and ndhF and ndhA and ndhB and...          0.0
#
#      Upper bound  Objective  Confidence Score  \
# 108       1000.0        0.0                 4
# 178       1000.0        0.0                 4
# 180       1000.0        0.0                 4
# 182       1000.0        0.0                 4
# 334       1000.0        0.0                 4
# 390       1000.0        0.0                 4
# 423       1000.0        0.0                 4
# 511       1000.0        0.0                 4
# 545       1000.0        0.0                 4
# 796       1000.0        0.0                 4
# 797       1000.0        0.0                 4
# 826       1000.0        0.0                 4
# 827       1000.0        0.0                 4
# 833       1000.0        0.0                 4
# 834       1000.0        0.0                 4
#
#                                              Subsystem  \
# 108                              Pyrimidine metabolism
# 178                          Oxidative phosphorylation
# 180                                     Photosynthesis
# 182                                Nitrogen metabolism
# 334         Valine leucine and isoleucine biosynthesis
# 390      Ubiquinone and other pterpenoids biosynthesis
# 423                              Vitamin B6 metabolism
# 511                    Arginine and proline metabolism
# 545  Phenylalanine tyrosine and tryptophan biosynth...
# 796                                          Transport
# 797                          Oxidative phosphorylation
# 826                          Oxidative phosphorylation
# 827                          Oxidative phosphorylation
# 833                          Oxidative phosphorylation
# 834                          Oxidative phosphorylation
#
#                                            Description
# 108                                  CTP synthase  NH3
# 178  Cytochrome oxidase bd (plastocianine-8  2 prot...
# 180  Cytochrome oxidase bd (plastocianine-8  2 prot...
# 182                   Glycine cleavage system, cytosol
# 334       Ketol-acid reductoisomerase (2-Acetolactate)
# 390                                Naphthoate synthase
# 423                   Pyridoxine 5'-phosphate synthase
# 511                                 L-serine deaminase
# 545     Tryptophan synthase (indoleglycerol phosphate)
# 796     Active co2 transporter facilitator (tilacoide)
# 797  NAD(P)H dehydrogenase (plastoquinone-8 & 3 pro...
# 826  NAD(P)H dehydrogenase (plastoquinone-8 & 3 pro...
# 827                                  ATP synthetase(u)
# 833  NAD(P)H dehydrogenase (plastoquinone-8 & 3 pro...
# 834  NAD(P)H dehydrogenase (plastoquinone-8 & 3 pro...

# %%
in_gene_name_column_dict.pop('psaK')
in_gene_name_column_dict = { key : list(value)[0] for key, value in in_gene_name_column_dict.items() }
in_gene_name_column_dict
# Out:
# {'ilvC': 'SGL_RS17215',
#  'pyrG': 'SGL_RS10805',
#  'atpA': 'SGL_RS02675',
#  'atpH': 'SGL_RS02680',
#  'ilvA': 'SGL_RS06140',
#  'atpC': 'SGL_RS09710',
#  'ndhI': 'SGL_RS16995',
#  'menB': 'SGL_RS06810',
#  'atpD': 'SGL_RS09705',
#  'gcvT': 'SGL_RS12745',
#  'pdxA': 'SGL_RS16360',
#  'hoxU': 'SGL_RS09745',
#  'ndhK': 'SGL_RS10730',
#  'psaB': 'SGL_RS06310',
#  'atpB': 'SGL_RS02700',
#  'hoxF': 'SGL_RS09755',
#  'cydB': 'SGL_RS05015',
#  'psaA': 'SGL_RS06305',
#  'psaM': 'SGL_RS04090',
#  'trpB': 'SGL_RS16740',
#  'atpE': 'SGL_RS02695',
#  'trpA': 'SGL_RS03395',
#  'ndhC': 'SGL_RS10725',
#  'psaC': 'SGL_RS12620',
#  'psaJ': 'SGL_RS09805'}

# %%
model_df[0].GPR.replace(in_gene_name_column_dict, regex=True, inplace=True)
model_df[0].loc[model_df[0].GPR.str.contains('|'.join(list(in_gene_name_column_dict.keys())))]
# Out:
# Empty DataFrame
# Columns: [Abbreviation, Reaction, GPR, Lower bound, Upper bound, Objective, Confidence Score, Subsystem, Description]
# Index: []

# %%
reannotated_model = dataframe_to_model(model_df[0], model_df[1])
reannotated_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ec_SynAuto = 0.08835348353030417</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.0003987</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>3.7</td>
#       <td>1</td>
#       <td>99.99%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>0.0002874</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.0002658</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.0006614</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0006022</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>2.42</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>0.8795</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.01495</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.002541</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>0.0002676</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mobd_e</td>
#       <td>EX_mobd_e</td>
#       <td>0.0002676</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.0003346</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>no3_e</td>
#       <td>EX_no3_e</td>
#       <td>0.7964</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon_e</td>
#       <td>EX_photon_e</td>
#       <td>54.1</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.06099</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.01676</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>0.0002658</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>rdmbzi_c</td>
#       <td>SK_rdmbzi_c</td>
#       <td>1.97E-05</td>
#       <td>14</td>
#       <td>0.01%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5mdru1p_c</td>
#       <td>DM_5mdru1p_c</td>
#       <td>-0.0005959</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>-5.585</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
not_in_new_annotation = set([g for r in reannotated_model.reactions for g in [gene.id for gene in r.genes] if g.startswith('SGL')==False ])
len(not_in_new_annotation)
# Out:
# 41

# %%
not_annotated_genes_in_new_model = set([gene for gene in not_in_new_annotation if gene in [g.id for g in new_model.genes]])
len(not_annotated_genes_in_new_model)
# Out:
# 7

# %%
not_annotated_genes_in_matlab_model = set([gene for gene in not_in_new_annotation if gene in [g.id for g in matlab_model.genes]])
len(not_annotated_genes_in_matlab_model)
# Out:
# 36

# %%
not_annotated_genes_in_new_model.intersection(not_annotated_genes_in_matlab_model)
# Out:
# {'sll8031', 'ssl3803'}

# %%
genes_with_annotated_traditional_names = set([gene for gene in not_in_new_annotation if gene in annot_table.gene_name.tolist()])
len(genes_with_annotated_traditional_names)
# Out:
# 0

# %%
not_reannotated_reactions = model_df[0].loc[model_df[0].GPR.str.contains('|'.join(list(not_in_new_annotation)))]
print('Still %s reactions to reannotate' % len(not_reannotated_reactions))
display(not_reannotated_reactions)
# Out:
# Still 38 reactions to reannotate
#     Abbreviation                                           Reaction  \
# 8        3OAR100  3odecACP_c + h_c + nadph_c <=> 3hdecACP_c + na...
# 10       3OAR120  3oddecACP_c + h_c + nadph_c <=> 3hddecACP_c + ...
# 12       3OAR140  3omrsACP_c + h_c + nadph_c --> 3hmrsACP_c + na...
# 15         ACONT                                   cit_c <=> icit_c
# 16       3OAR160  3opalmACP_c + h_c + nadph_c <=> 3hpalmACP_c + ...
# 19       3OAR180  3ooctdACP_c + h_c + nadph_c --> 3hoctaACP_c + ...
# 23           FQR  2.0 fdxrd_c + 2.0 h_c + pq_u --> 2.0 fdxo_2_2_...
# 27        3OAR40     actACP_c + h_c + nadph_c <=> 3haACP_c + nadp_c
# 31        3OAR60  3ohexACP_c + h_c + nadph_c <=> 3hhexACP_c + na...
# 51        3OAR80  3ooctACP_c + h_c + nadph_c <=> 3hoctACP_c + na...
# 54      BCAROHX2  bcryptox_c + h_c + nadph_c + o2_c --> h2o_c + ...
# 55       BCAROHX  caro_c + h_c + nadph_c + o2_c --> bcryptox_c +...
# 78         CBFCu  2.0 h_c + 2.0 pcox_u + pqh2_u --> 4.0 h_u + 2....
# 130         AMID            4gudbd_c + h2o_c --> 4gudbutn_c + nh4_c
# 178    CYTBDpp_1                 0.5 o2_p + pqh2_p --> h2o_p + pq_p
# 180       CYTBDu                 0.5 o2_u + pqh2_u --> h2o_u + pq_u
# 243       DES_12  2.0 fdxrd_c + 2.0 h_c + o2_c + octe_9_ACP_c --...
# 252       DES_15  2.0 fdxrd_c + 2.0 h_c + o2_c + octe_9_12_ACP_c...
# 258        DES_6  2.0 fdxrd_c + 2.0 h_c + o2_c + octe_9_12_15_AC...
# 265       DES_6B  2.0 fdxrd_c + 2.0 h_c + o2_c + octe_9_12_ACP_c...
# 271        DES_9  2.0 fdxrd_c + 2.0 h_c + o2_c + ocdcaACP_c --> ...
# 302       DHORDi               dhor__S_c + o2_c <=> h2o2_c + orot_c
# 325       LEUTAi             4mop_c + glu__L_c --> akg_c + leu__L_c
# 461         PSII  h2o_u + 2.0 h_c + 2.0 photon_c + pq_u --> 2.0 ...
# 485         PYK3              gdp_c + h_c + pep_c --> gtp_c + pyr_c
# 487         PYK4              cdp_c + h_c + pep_c --> ctp_c + pyr_c
# 533     PHBS_syn             3hbcoa__R_c + phbg_c --> PHB_c + coa_c
# 783    H2Otu_syn                                    h2o_u <=> h2o_c
# 796      NDH1_3u  co2_p + h2o_c + 3.0 h_c + nadph_c + pq_u --> 3...
# 797      NDH1_1u  4.0 h_c + nadph_c + pq_u --> 3.0 h_u + nadp_c ...
# 821     NDH1_4pp  co2_p + h2o_c + 3.0 h_c + nadph_c + pq_p --> 3...
# 826      NDH1_2p  4.0 h_c + nadh_c + pq_p --> 3.0 h_p + nad_c + ...
# 827        ATPSu  3.0 adp_c + 14.0 h_u + 3.0 pi_c --> 3.0 atp_c ...
# 833      NDH1_2u  4.0 h_c + nadh_c + pq_u --> 3.0 h_u + nad_c + ...
# 834      NDH1_1p  4.0 h_c + nadph_c + pq_p --> 3.0 h_p + nadp_c ...
# 856      CBFC2pp  2.0 ficytc6_p + 2.0 h_c + pqh2_p --> 2.0 focyt...
# 857        CBFC2  2.0 ficytc6_u + 2.0 h_c + pqh2_u --> 2.0 focyt...
# 858       CBFCpp  2.0 h_c + 2.0 pcox_p + pqh2_p --> 4.0 h_p + 2....
#
#                                                    GPR  Lower bound  \
# 8                SGL_RS07245 or SGL_RS12965 or sll5079      -1000.0
# 10               SGL_RS07245 or SGL_RS12965 or sll5079      -1000.0
# 12               SGL_RS07245 or SGL_RS12965 or sll5079          0.0
# 15                                             slr0665      -1000.0
# 16               SGL_RS07245 or SGL_RS12965 or sll5079      -1000.0
# 19               SGL_RS07245 or SGL_RS12965 or sll5079          0.0
# 23                                             ssr2016          0.0
# 27               SGL_RS07245 or SGL_RS12965 or sll5079      -1000.0
# 31               SGL_RS07245 or SGL_RS12965 or sll5079      -1000.0
# 51               SGL_RS07245 or SGL_RS12965 or sll5079      -1000.0
# 54                                                 bhy          0.0
# 55                                                 bhy          0.0
# 78   SGL_RS05875 and SGL_RS07315 and SGL_RS13200 an...          0.0
# 130                                               nylA          0.0
# 178                               cydA and SGL_RS05015          0.0
# 180                               cydA and SGL_RS05015          0.0
# 243                                               desA          0.0
# 252                                               desB          0.0
# 258                                         desD_des6_          0.0
# 265                                         desD_des6_          0.0
# 271                                         desC_des9_          0.0
# 302                                               pyrD      -1000.0
# 325                                               ilvE          0.0
# 461  SGL_RS11935 and SGL_RS11735 and SGL_RS08205 an...          0.0
# 485                                       pykF or pykF          0.0
# 487                                       pykF or pykF          0.0
# 533                                   slr1829 and phbC          0.0
# 783                                               apqZ      -1000.0
# 796  ndhA and ndhB and SGL_RS10725 and ndhE and ndh...          0.0
# 797  (ndhD or ndhD2) and ndhF and ndhA and ndhB and...          0.0
# 821  sll8031 and SGL_RS06280 and SGL_RS09760 and SG...          0.0
# 826  (ndhD or ndhD2) and ndhF and ndhA and ndhB and...          0.0
# 827  atpI and atpG and atpF and SGL_RS02675 and SGL...          0.0
# 833  (ndhD or ndhD2) and ndhF and ndhA and ndhB and...          0.0
# 834  (ndhD or ndhD2) and ndhF and ndhA and ndhB and...          0.0
# 856  SGL_RS05875 and SGL_RS07315 and SGL_RS13200 an...          0.0
# 857  SGL_RS05875 and SGL_RS07315 and SGL_RS13200 an...          0.0
# 858  SGL_RS05875 and SGL_RS07315 and SGL_RS13200 an...          0.0
#
#      Upper bound  Objective  Confidence Score  \
# 8         1000.0        0.0                 4
# 10        1000.0        0.0                 4
# 12        1000.0        0.0                 4
# 15        1000.0        0.0                 4
# 16        1000.0        0.0                 4
# 19        1000.0        0.0                 4
# 23        1000.0        0.0                 4
# 27        1000.0        0.0                 4
# 31        1000.0        0.0                 4
# 51        1000.0        0.0                 4
# 54        1000.0        0.0                 4
# 55        1000.0        0.0                 4
# 78        1000.0        0.0                 4
# 130       1000.0        0.0                 4
# 178       1000.0        0.0                 4
# 180       1000.0        0.0                 4
# 243       1000.0        0.0                 4
# 252       1000.0        0.0                 4
# 258       1000.0        0.0                 4
# 265       1000.0        0.0                 4
# 271       1000.0        0.0                 4
# 302       1000.0        0.0                 4
# 325       1000.0        0.0                 4
# 461       1000.0        0.0                 4
# 485       1000.0        0.0                 4
# 487       1000.0        0.0                 4
# 533       1000.0        0.0                 4
# 783       1000.0        0.0                 4
# 796       1000.0        0.0                 4
# 797       1000.0        0.0                 4
# 821       1000.0        0.0                 4
# 826       1000.0        0.0                 4
# 827       1000.0        0.0                 4
# 833       1000.0        0.0                 4
# 834       1000.0        0.0                 4
# 856       1000.0        0.0                 4
# 857       1000.0        0.0                 4
# 858       1000.0        0.0                 4
#
#                                       Subsystem  \
# 8                       Fatty acid biosynthesis
# 10                      Fatty acid biosynthesis
# 12                      Fatty acid biosynthesis
# 15                    Citrate cycle (TCA cycle)
# 16                      Fatty acid biosynthesis
# 19                      Fatty acid biosynthesis
# 23                               Photosynthesis
# 27                      Fatty acid biosynthesis
# 31                      Fatty acid biosynthesis
# 51                      Fatty acid biosynthesis
# 54                      Carotenoid Biosynthesis
# 55                      Carotenoid Biosynthesis
# 78                               Photosynthesis
# 130             Arginine and proline metabolism
# 178                   Oxidative phosphorylation
# 180                              Photosynthesis
# 243                     Fatty acid biosynthesis
# 252                     Fatty acid biosynthesis
# 258                     Fatty acid biosynthesis
# 265                     Fatty acid biosynthesis
# 271                     Fatty acid biosynthesis
# 302                       Pyrimidine metabolism
# 325  Valine leucine and isoleucine biosynthesis
# 461                              Photosynthesis
# 485                  Glycolysis/Gluconeogenesis
# 487                  Glycolysis/Gluconeogenesis
# 533                            PHB byosynthesis
# 783                                   Transport
# 796                                   Transport
# 797                   Oxidative phosphorylation
# 821                                   Transport
# 826                   Oxidative phosphorylation
# 827                   Oxidative phosphorylation
# 833                   Oxidative phosphorylation
# 834                   Oxidative phosphorylation
# 856                   Oxidative phosphorylation
# 857                              Photosynthesis
# 858                   Oxidative phosphorylation
#
#                                            Description
# 8    3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# 10   3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# 12   3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# 15                                 Aconitate hydratase
# 16   3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# 19   3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# 23                                Cyclic Electron Flow
# 27   3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# 31   3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# 51   3-oxoacyl-[acyl-carrier-protein] reductase (n-...
# 54                           Beta-carotene hydroxylase
# 55                           Beta-carotene hydroxylase
# 78                             Cytochrome b6/f complex
# 130                        GUANIDINOBUTANAMIDE-NH3-RXN
# 178  Cytochrome oxidase bd (plastocianine-8  2 prot...
# 180  Cytochrome oxidase bd (plastocianine-8  2 prot...
# 243      Stearoyl-CoA desaturase (delta-12 desaturase)
# 252      Stearoyl-CoA desaturase (delta-15 desaturase)
# 258       Stearoyl-CoA desaturase (delta-6 desaturase)
# 265       Stearoyl-CoA desaturase (delta-6 desaturase)
# 271       Stearoyl-CoA desaturase (delta-9 desaturase)
# 302      Dihydoorotic acid dehydrogenase  irreversible
# 325                Leucine transaminase (irreversible)
# 461                                     Photosystem II
# 485                                 Pyruvate kinase(3)
# 487                                 Pyruvate kinase(4)
# 533                                     PHB synthetasa
# 783             H2O transport via diffusion (tilacoid)
# 796     Active co2 transporter facilitator (tilacoide)
# 797  NAD(P)H dehydrogenase (plastoquinone-8 & 3 pro...
# 821     Active co2 transporter facilitator (periplasm)
# 826  NAD(P)H dehydrogenase (plastoquinone-8 & 3 pro...
# 827                                  ATP synthetase(u)
# 833  NAD(P)H dehydrogenase (plastoquinone-8 & 3 pro...
# 834  NAD(P)H dehydrogenase (plastoquinone-8 & 3 pro...
# 856                  Cytochrome b6/f complex periplasm
# 857                            Cytochrome b6/f complex
# 858                  Cytochrome b6/f complex periplasm

# %% [markdown]
# Now, we have reannotated all genes with traditional names but **for several issues there are still 38 reactions to reannotate**. As there is no common reason for the missed reannotation, **I manually checked all reactions in the previous df, creating a dictionary with the final substitutions**. This manual curation was done with the aid of **BIGG database**, which was used to check for matching reactions and for retrieving old locus tags unavailable in *iJN678*.

# %%
final_reannotation_dict = { 'sll5079' : 'SGL_RS00360',
                            'slr0665' : 'SGL_RS17360',
                            'ssr2016' : 'SGL_RS06050',
                            'bhy' : 'SGL_RS06460',
                            ' and ssl3803' : '',
                            ' and sml0004' : '',
                            'nylA' : 'SGL_RS15160',
                            'cydA' : 'SGL_RS05010',
                            'desA' : 'SGL_RS10130',
                            'desB' : 'SGL_RS10825',
                            'desD_des6_' : 'SGL_RS11885',
                            'desC_des9_' : 'SGL_RS15040',
                            'pyrD' : 'SGL_RS17005',
                            'ilvE' : 'SGL_RS16510',
                            ' and sml0003' : '',
                            ' and smr0009' : '',
                            'pykF or pykF' : 'SGL_RS15640 or SGL_RS07035',
                            'slr1829' : 'SGL_RS06265',
                            'phbC' : 'SGL_RS06270',
                            'apqZ' : 'SGL_RS08525',
                            'ndhA' : 'SGL_RS17000',
                            'ndhB' : 'SGL_RS02610',
                            'ndhE' : 'SGL_RS16985',
                            'ndhG' : 'SGL_RS16990',
                            'ndhH' : 'SGL_RS08920',
                            'ndhJ' : 'SGL_RS10735',
                            '(SGL_RS10730 or sll8031)' : 'SGL_RS10730',
                            'slr1623' : 'SGL_RS11490',
                            'sll1262' : 'SGL_RS09990',
                            'sll1220' : 'SGL_RS09760',
                            'ndhD3' : 'SGL_RS06290',
                            'ndhF' : 'SGL_RS16595 and SGL_RS06295 and SGL_RS15190',
                            'sll1734' : 'SGL_RS06285',
                            'sll1735' : 'SGL_RS06280',
                            '(ndhD or ndhD2)' : 'SGL_RS16590 and SGL_RS12625 and SGL_RS03225',
                            'sll8031 and ' : '',
                            'ssl0352 and ' : '',
                            'atpI and atpG and atpF and SGL_RS02675 and SGL_RS09705 and SGL_RS09710 and SGL_RS02700 and SGL_RS02695 and SGL_RS02680 and atp1' : 'SGL_RS02705 and SGL_RS02670 and SGL_RS02690 and SGL_RS02700 and SGL_RS02695 and SGL_RS02685 and SGL_RS02680 and SGL_RS02675 and SGL_RS09705 and SGL_RS09710',
                            }

# %%
model_df[0].GPR.replace(final_reannotation_dict, regex=True, inplace=True)
reannotated_model = dataframe_to_model(model_df[0], model_df[1])
reannotated_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ec_SynAuto = 0.08835348353030417</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.0003987</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>3.7</td>
#       <td>1</td>
#       <td>99.99%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>0.0002874</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.0002658</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.0006614</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0006022</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>2.42</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>0.8795</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.01495</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.002541</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e</td>
#       <td>0.0002676</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mobd_e</td>
#       <td>EX_mobd_e</td>
#       <td>0.0002676</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>na1_e</td>
#       <td>EX_na1_e</td>
#       <td>0.0003346</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>no3_e</td>
#       <td>EX_no3_e</td>
#       <td>0.7964</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>photon_e</td>
#       <td>EX_photon_e</td>
#       <td>54.1</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.06099</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.01676</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e</td>
#       <td>0.0002658</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>rdmbzi_c</td>
#       <td>SK_rdmbzi_c</td>
#       <td>1.97E-05</td>
#       <td>14</td>
#       <td>0.01%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5mdru1p_c</td>
#       <td>DM_5mdru1p_c</td>
#       <td>-0.0005959</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>-5.585</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
not_in_new_annotation = set([g for r in reannotated_model.reactions for g in [gene.id for gene in r.genes] if g.startswith('SGL')==False ])
len(not_in_new_annotation)
# Out:
# 0

# %% [markdown]
# Finally all the GPRs are reannotated so now I will **save the model**

# %%
final_model_filepath = '/'.join(['models', 'iJN678_new_annotation.mat'])
cobra.io.save_matlab_model(reannotated_model, final_model_filepath)
